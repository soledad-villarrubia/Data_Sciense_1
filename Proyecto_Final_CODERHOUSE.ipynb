# %% [markdown]
# <a href="https://colab.research.google.com/github/soledad-villarrubia/Data_Sciense_1/blob/main/Proyecto_Final_CODERHOUSE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar librerías
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import warnings

# %%
# Configuraciones opcionales para mejor visualización
sns.set_theme(style="whitegrid") # Establece un tema estético para los gráficos
plt.rcParams['figure.figsize'] = (12, 6) # Establece un tamaño de figura por defecto
warnings.filterwarnings('ignore') # Ignora advertencias (útil para presentaciones)

# %%
import requests

url = "https://github.com/soledad-villarrubia/Data_Sciense_1/raw/refs/heads/main/Dataset%20Siniestros%20de%20Motos%20Robo%20Total.csv"

response = requests.get(url)  # Hace una solicitud GET para obtener el contenido del archivo
print(response.text[:300])  # Imprime los primeros 300 caracteres del archivo para ver cómo está delimitado
response = requests.get(url)  # Hace una solicitud GET para obtener el contenido del archivo
print(response.text[:300])  # Imprime los primeros 300 caracteres del archivo para ver cómo está delimitado
# Out:
# id_Siniestro;Importe pagado ;Estado;Fecha Siniestro;Mes_Año;Mes;Año;Unidad de Negocio;Id_PAS;Localidad de Ocurrencia;CP;Provincia;Marca;Modelo;Versión;Año;Suma Asegurada
# 153;185000;CERRADO;2/7/2022;jul-22;Julio;2022;Buenos Aires;126;GRAND BOURG;1615;Buenos Aires;GUERRERO;ENDURO;150 GXL TUNDRA;2017;
# id_Siniestro;Importe pagado ;Estado;Fecha Siniestro;Mes_Año;Mes;Año;Unidad de Negocio;Id_PAS;Localidad de Ocurrencia;CP;Provincia;Marca;Modelo;Versión;Año;Suma Asegurada
# 153;185000;CERRADO;2/7/2022;jul-22;Julio;2022;Buenos Aires;126;GRAND BOURG;1615;Buenos Aires;GUERRERO;ENDURO;150 GXL TUNDRA;2017;

# %%
df = pd.read_csv(url, sep=';', encoding='latin1') # lee el archivo,

df.head()# Muestra las primeras 5 filas
# Out:
#    id_Siniestro  Importe pagado    Estado Fecha Siniestro Mes_Año         Mes  \
# 0           153           185000  CERRADO        2/7/2022  jul-22       Julio
# 1           735           215000  CERRADO       23/9/2022  sep-22  Septiembre
# 2           576            84000  CERRADO       31/8/2022  ago-22      Agosto
# 3          1727           344500  CERRADO       13/1/2023  ene-23       Enero
# 4          1683           248000  CERRADO        8/1/2023  ene-23       Enero
#
#     Año Unidad de Negocio  Id_PAS Localidad de Ocurrencia    CP  \
# 0  2022      Buenos Aires     126             GRAND BOURG  1615
# 1  2022      Buenos Aires     438             VILLA MAIPU  1650
# 2  2022               USE      11                  MORENO  1740
# 3  2023      Buenos Aires      45                C.A.B.A.  1000
# 4  2023               USE      11             RAMOS MEJIA  1704
#
#               Provincia     Marca  Modelo                       Versión Año.1  \
# 0          Buenos Aires  GUERRERO  ENDURO                150 GXL TUNDRA  2017
# 1          Buenos Aires   MOTOMEL  STREET             150 S2 BASE DISCO  2022
# 2          Buenos Aires   ZANELLA     CUB  ZB 110 G4 ARRANQUE ELECTRICO  2013
# 3  C.A. de Buenos Aires    YAMAHA  STREET                    125 YBR ED  2014
# 4          Buenos Aires   ZANELLA     CUB                ZB 110 Z1 BASE  2022
#
#    Suma Asegurada
# 0          185000
# 1          215000
# 2           84000
# 3          344500
# 4          248000

# %%
df.describe()  # Estadísticas básicas de columnas numéricas
# Out:
#        id_Siniestro  Importe pagado           Año       Id_PAS  Suma Asegurada
# count   9944.000000     9.944000e+03  9944.000000  9944.000000    9.944000e+03
# mean    4972.500000     1.551408e+06  2023.159393   623.708970    1.458629e+06
# std     2870.729872     2.277792e+06     0.678128   625.072234    1.881155e+06
# min        1.000000     0.000000e+00  2022.000000     1.000000    0.000000e+00
# 25%     2486.750000     3.213395e+05  2023.000000    66.000000    3.991250e+05
# 50%     4972.500000     8.251995e+05  2023.000000   410.000000    8.405000e+05
# 75%     7458.250000     1.913694e+06  2024.000000  1066.000000    1.835000e+06
# max     9944.000000     4.628932e+07  2024.000000  2314.000000    4.628932e+07

# %%
df.info()      # muestra tipos de datos y valores no nulos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9944 entries, 0 to 9943
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id_Siniestro             9944 non-null   int64
#  1   Importe pagado           9944 non-null   int64
#  2   Estado                   9944 non-null   object
#  3   Fecha Siniestro          9944 non-null   object
#  4   Mes_Año                  9944 non-null   object
#  5   Mes                      9944 non-null   object
#  6   Año                      9944 non-null   int64
#  7   Unidad de Negocio        9944 non-null   object
#  8   Id_PAS                   9944 non-null   int64
#  9   Localidad de Ocurrencia  9944 non-null   object
#  10  CP                       9944 non-null   object
#  11  Provincia                9944 non-null   object
#  12  Marca                    9944 non-null   object
#  13  Modelo                   9944 non-null   object
#  14  Versión                  9944 non-null   object
#  15  Año.1                    9944 non-null   object
#  16  Suma Asegurada           9944 non-null   int64
# dtypes: int64(5), object(12)
# memory usage: 1.3+ MB

# %%
df.isnull().sum()  # Cuenta valores faltantes por columna
# Out:
# id_Siniestro               0
# Importe pagado             0
# Estado                     0
# Fecha Siniestro            0
# Mes_Año                    0
# Mes                        0
# Año                        0
# Unidad de Negocio          0
# Id_PAS                     0
# Localidad de Ocurrencia    0
# CP                         0
# Provincia                  0
# Marca                      0
# Modelo                     0
# Versión                    0
# Año.1                      0
# Suma Asegurada             0
# dtype: int64

# %%
df['Importe pagado '] = df['Importe pagado '].astype(float)
df['Suma Asegurada'] = df['Suma Asegurada'].astype(float)

# %%
# transformar una columna de tipo object (o string) a datetime y darle formato: día/mes/año
df['Fecha Siniestro'] = pd.to_datetime(df['Fecha Siniestro'], format='%d/%m/%Y')

# %%
# transformar una columna de tipo object (o string) a datetime y darle formato: mes/año
df['Mes_Año'] = pd.to_datetime(df['Mes_Año'], format='%b-%y', errors='coerce')

# %%
sinistros_por_fecha = df.groupby('Mes_Año').size() # Agrupar por fecha y contar los siniestros

# %%
# Gráfico Evolución de Siniestros ingresados por Mes y Año
plt.figure(figsize=(12, 6))
sinistros_por_fecha.plot(kind='line', marker='o')
plt.title('Evolución de Siniestros Ingresados')
plt.xlabel('Fecha')
plt.ylabel('Número de Siniestros')
plt.xticks(rotation=45)
# plt.grid() # commented out to remove the grid
for x, y in zip(sinistros_por_fecha.index, sinistros_por_fecha.values):
    plt.text(x, y, str(y), ha='center', va='bottom', fontsize=9)
plt.show()
